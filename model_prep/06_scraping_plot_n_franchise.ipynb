# %%
import re
import time
import random
import requests
import pandas as pd

from pathlib import Path
from bs4 import BeautifulSoup

ROOT = Path.cwd().parent
print(ROOT)
# Out:
# c:\Users\sebas\PycharmProjects\Git\BoxOffice_Oracle

# %%
DATA_PROCESSED = ROOT/"data/processed"
CACHE_DIR = ROOT/"data/cache/the_numbers_pages"

INPUT_PATH = DATA_PROCESSED / "scrape_ready_us_production_filtered.csv"
OUTPUT_PATH = DATA_PROCESSED / "the_numbers_plot_franchise.csv"

scrape_df = pd.read_csv(INPUT_PATH)

scrape_df = scrape_df[
    scrape_df["the_numbers_url"].notna()
].drop_duplicates(subset="tconst").reset_index(drop=True)

print(scrape_df.shape)
scrape_df.head()
# Out:
# (2316, 9)
#       tconst                                  primaryTitle  startYear  \
# 0  tt0120667                                Fantastic Four     2005.0
# 1  tt0121164                                  Corpse Bride     2005.0
# 2  tt0121766  Star Wars: Episode III - Revenge of the Sith     2005.0
# 3  tt0167190                                       Hellboy     2004.0
# 4  tt0200465                                  The Bank Job     2008.0
#
#                                      the_numbers_url  found_url  \
# 0  https://www.the-numbers.com/movie/Fantastic-Fo...       True
# 1     https://www.the-numbers.com/movie/Corpse-Bride       True
# 2  https://www.the-numbers.com/movie/Star-Wars-Ep...       True
# 3          https://www.the-numbers.com/movie/Hellboy       True
# 4     https://www.the-numbers.com/movie/Bank-Job-The       True
#
#                             normalized_title  kaggle_year  \
# 0                             fantastic four         2005
# 1                               corpse bride         2005
# 2  star wars episode iii revenge of the sith         2005
# 3                                    hellboy         2004
# 4                               the bank job         2008
#
#                                    kaggle_title  \
# 0                                Fantastic Four
# 1                                  Corpse Bride
# 2  Star Wars: Episode III - Revenge of the Sith
# 3                                       Hellboy
# 4                                  The Bank Job
#
#                                 Production_Countries
# 0                  Germany, United States of America
# 1           United Kingdom, United States of America
# 2                           United States of America
# 3           Czech Republic, United States of America
# 4  Australia, United Kingdom, United States of Am...

# %%
headers = {
    "User-Agent": "Mozilla/5.0"
}

def clean_cache_name(text):
    text = str(text)
    text = re.sub(r"[^a-zA-Z0-9]+", "_", text)
    return text.strip("_")[:120]


def fetch_the_numbers_html(row):
    tconst = row["tconst"]
    url = row["the_numbers_url"]

    cache_path = CACHE_DIR / f"{clean_cache_name(tconst)}.html"

    if cache_path.exists():
        return cache_path.read_text(encoding="utf-8", errors="ignore")

    response = requests.get(url, headers=headers, timeout=25)
    response.raise_for_status()

    html = response.text
    cache_path.write_text(html, encoding="utf-8", errors="ignore")

    time.sleep(2.5 + random.uniform(0, 1))

    return html

# %%
def get_lines_from_html(html):
    soup = BeautifulSoup(html, "html.parser")

    lines = [
        re.sub(r"\s+", " ", x).strip()
        for x in soup.stripped_strings
    ]

    return [line for line in lines if line]

# %%
def get_field(lines, label):

    normalized_label = label.rstrip(":")

    for i, line in enumerate(lines):

        clean_line = line.strip()

        if clean_line.rstrip(":") == normalized_label:

            # look ahead until non-empty
            for j in range(i + 1, len(lines)):

                candidate = lines[j].strip()

                if candidate:
                    return candidate

        if clean_line.startswith(f"{normalized_label}:"):

            value = clean_line.split(":", 1)[1].strip()

            if value:
                return value

    return None

# %%
def extract_synopsis(lines):

    synopsis = get_field(lines, "Synopsis")

    if synopsis:
        synopsis = synopsis.strip()

    return synopsis

# %%
def extract_franchise(lines):

    franchise = get_field(lines, "Franchise")

    if franchise:
        franchise = franchise.strip()

    return franchise

# %%
def parse_plot_and_franchise(html):

    lines = get_lines_from_html(html)

    return {
        "plot_summary": extract_synopsis(lines),
        "franchise": extract_franchise(lines),
    }

# %%
test_rows = scrape_df.sample(10, random_state=42)

test_results = []

for _, row in test_rows.iterrows():
    html = fetch_the_numbers_html(row)
    parsed = parse_plot_and_franchise(html)

    test_results.append({
        "tconst": row["tconst"],
        "primaryTitle": row["primaryTitle"],
        "the_numbers_url": row["the_numbers_url"],
        **parsed
    })

test_df = pd.DataFrame(test_results)

test_df[[
    "primaryTitle",
    "plot_summary",
    "franchise"
]]
# Out:
#                             primaryTitle  \
# 0                           Breakthrough
# 1                           The Covenant
# 2                                Miracle
# 3                          Bones and All
# 4                         Seed of Chucky
# 5                          She's the Man
# 6                               The Menu
# 7  The Ministry of Ungentlemanly Warfare
# 8                              Spanglish
# 9        Transformers: Age of Extinction
#
#                                         plot_summary     franchise
# 0  The true story of one mother’s unfaltering lov...           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3  A story of first love between Maren, a young w...           NaN
# 4                                                NaN  Child's Play
# 5  Viola Johnson is in a real jam. Complications ...           NaN
# 6  Set in the world of high-end culinary culture,...           NaN
# 7  The story of the first-ever special forces org...           NaN
# 8                                                NaN           NaN
# 9  An epic battle left a great city torn, but wit...  Transformers

# %%
rows = []

start_time = time.time()

for i, (_, row) in enumerate(scrape_df.iterrows(), start=1):

    record = {
        "tconst": row["tconst"],
        "primaryTitle": row.get("primaryTitle"),
        "startYear": row.get("startYear"),
        "the_numbers_url": row["the_numbers_url"],
        "scrape_success": False,
        "scrape_error": None,
    }

    try:
        html = fetch_the_numbers_html(row)
        parsed = parse_plot_and_franchise(html)

        record.update(parsed)
        record["scrape_success"] = True

    except Exception as e:
        record["scrape_error"] = str(e)

    rows.append(record)

    if i % 100 == 0:
        elapsed = (time.time() - start_time) / 60
        found_plot = sum(r.get("plot_summary") is not None for r in rows)
        found_franchise = sum(r.get("franchise") is not None for r in rows)

        print(
            f"[{i}/{len(scrape_df)}] "
            f"Plot found: {found_plot} | "
            f"Franchise found: {found_franchise} | "
            f"Elapsed: {elapsed:.2f} min"
        )

plot_franchise_df = pd.DataFrame(rows)

plot_franchise_df.to_csv(OUTPUT_PATH, index=False)

print(plot_franchise_df.shape)
plot_franchise_df.head()
# Out:
# [100/2316] Plot found: 29 | Franchise found: 34 | Elapsed: 0.15 min
# [200/2316] Plot found: 56 | Franchise found: 70 | Elapsed: 0.29 min
# [300/2316] Plot found: 89 | Franchise found: 98 | Elapsed: 0.42 min
# [400/2316] Plot found: 122 | Franchise found: 122 | Elapsed: 0.57 min
# [500/2316] Plot found: 154 | Franchise found: 153 | Elapsed: 0.74 min
# [600/2316] Plot found: 190 | Franchise found: 183 | Elapsed: 0.93 min
# [700/2316] Plot found: 241 | Franchise found: 209 | Elapsed: 1.11 min
# [800/2316] Plot found: 287 | Franchise found: 236 | Elapsed: 1.30 min
# [900/2316] Plot found: 347 | Franchise found: 266 | Elapsed: 1.50 min
# [1000/2316] Plot found: 417 | Franchise found: 295 | Elapsed: 1.69 min
# [1100/2316] Plot found: 491 | Franchise found: 332 | Elapsed: 1.89 min
# [1200/2316] Plot found: 577 | Franchise found: 369 | Elapsed: 2.09 min
# [1300/2316] Plot found: 670 | Franchise found: 399 | Elapsed: 2.31 min
# [1400/2316] Plot found: 766 | Franchise found: 434 | Elapsed: 2.50 min
# [1500/2316] Plot found: 860 | Franchise found: 464 | Elapsed: 2.72 min
# [1600/2316] Plot found: 952 | Franchise found: 498 | Elapsed: 2.92 min
# [1700/2316] Plot found: 1049 | Franchise found: 538 | Elapsed: 3.15 min
# [1800/2316] Plot found: 1144 | Franchise found: 570 | Elapsed: 3.35 min
# [1900/2316] Plot found: 1239 | Franchise found: 608 | Elapsed: 3.54 min
# [2000/2316] Plot found: 1336 | Franchise found: 657 | Elapsed: 3.77 min
# [2100/2316] Plot found: 1434 | Franchise found: 691 | Elapsed: 3.98 min
# [2200/2316] Plot found: 1526 | Franchise found: 732 | Elapsed: 4.19 min
# [2300/2316] Plot found: 1626 | Franchise found: 763 | Elapsed: 4.37 min
# (2316, 8)
#       tconst                                  primaryTitle  startYear  \
# 0  tt0120667                                Fantastic Four     2005.0
# 1  tt0121164                                  Corpse Bride     2005.0
# 2  tt0121766  Star Wars: Episode III - Revenge of the Sith     2005.0
# 3  tt0167190                                       Hellboy     2004.0
# 4  tt0200465                                  The Bank Job     2008.0
#
#                                      the_numbers_url  scrape_success  \
# 0  https://www.the-numbers.com/movie/Fantastic-Fo...            True
# 1     https://www.the-numbers.com/movie/Corpse-Bride            True
# 2  https://www.the-numbers.com/movie/Star-Wars-Ep...            True
# 3          https://www.the-numbers.com/movie/Hellboy            True
# 4     https://www.the-numbers.com/movie/Bank-Job-The            True
#
#   scrape_error                                       plot_summary  \
# 0         None  Scientist Reed Richards persuades his arrogant...
# 1         None                                                NaN
# 2         None  Years after the onset of the Clone Wars, the n...
# 3         None                                                NaN
# 4         None  Self-reformed petty criminal Terry Leather has...
#
#         franchise
# 0  Fantastic Four
# 1             NaN
# 2       Star Wars
# 3         Hellboy
# 4             NaN

# %%
plot_franchise_df[[
    "plot_summary",
    "franchise",
    "scrape_success",
    "scrape_error"
]].isna().mean()
# Out:
# plot_summary      0.291451
# franchise         0.667530
# scrape_success    0.000000
# scrape_error      1.000000
# dtype: float64

# %%
plot_franchise_df["has_plot_summary"] = (
    plot_franchise_df["plot_summary"].notna()
)

# %%
plot_franchise_df[
    plot_franchise_df["plot_summary"].isna()
][["primaryTitle", "the_numbers_url"]].sample(20, random_state=42)
# Out:
#                                 primaryTitle  \
# 580                            The Strangers
# 436                               Hoodwinked
# 2182                           Truth or Dare
# 870                             The Proposal
# 546                            State of Play
# 77                                  Cellular
# 1577                            No Good Deed
# 371                                Surf's Up
# 1954                              Bride Wars
# 734                    The Forbidden Kingdom
# 78                     Live Free or Die Hard
# 1443                         Haunted Mansion
# 739                                Baby Mama
# 108                                De-Lovely
# 335                            Evan Almighty
# 399                                The Women
# 438                             The Sentinel
# 452                                  Hancock
# 124   Agent Cody Banks 2: Destination London
# 693                           The Stepfather
#
#                                         the_numbers_url
# 580   https://www.the-numbers.com/movie/Strangers-Th...
# 436        https://www.the-numbers.com/movie/Hoodwinked
# 2182  https://www.the-numbers.com/movie/Truth-or-Dar...
# 870      https://www.the-numbers.com/movie/Proposal-The
# 546     https://www.the-numbers.com/movie/State-of-Play
# 77           https://www.the-numbers.com/movie/Cellular
# 1577     https://www.the-numbers.com/movie/No-Good-Deed
# 371   https://www.the-numbers.com/movie/Surfs-Up-(2007)
# 1954       https://www.the-numbers.com/movie/Bride-Wars
# 734   https://www.the-numbers.com/movie/Forbidden-Ki...
# 78    https://www.the-numbers.com/movie/Live-Free-or...
# 1443  https://www.the-numbers.com/movie/Haunted-Mans...
# 739         https://www.the-numbers.com/movie/Baby-Mama
# 108         https://www.the-numbers.com/movie/De-Lovely
# 335     https://www.the-numbers.com/movie/Evan-Almighty
# 399   https://www.the-numbers.com/movie/Women-The-(2...
# 438      https://www.the-numbers.com/movie/Sentinel-The
# 452    https://www.the-numbers.com/movie/Hancock-(2008)
# 124   https://www.the-numbers.com/movie/Agent-Cody-B...
# 693   https://www.the-numbers.com/movie/Stepfather-T...

# %%
plot_franchise_df.to_csv(
    ROOT/"data/processed/the_numbers_plot_franchise.csv",
    index=False
)

print("Saved successfully.")
# Out:
# Saved successfully.

# %%
DATA_RAW = ROOT/"data/raw"
model_df = pd.read_csv(
    DATA_RAW/"default_model_df.csv"
)

print(model_df.shape)
model_df.head()
# Out:
# (2255, 47)
#    Unnamed: 0     tconst                                  primaryTitle  \
# 0           0  tt0120667                                Fantastic Four
# 1           1  tt0121164                                  Corpse Bride
# 2           2  tt0121766  Star Wars: Episode III - Revenge of the Sith
# 3           3  tt0167190                                       Hellboy
# 4           4  tt0200465                                  The Bank Job
#
#    startYear                                    the_numbers_url  \
# 0     2005.0  https://www.the-numbers.com/movie/Fantastic-Fo...
# 1     2005.0     https://www.the-numbers.com/movie/Corpse-Bride
# 2     2005.0  https://www.the-numbers.com/movie/Star-Wars-Ep...
# 3     2004.0          https://www.the-numbers.com/movie/Hellboy
# 4     2008.0     https://www.the-numbers.com/movie/Bank-Job-The
#
#    scrape_success  scrape_error  opening_weekend_gross  opening_theaters  \
# 0            True           NaN             56061504.0            3602.0
# 1            True           NaN             19145480.0            3204.0
# 2            True           NaN            108435841.0            3661.0
# 3            True           NaN             23172440.0            3028.0
# 4            True           NaN              5935256.0            1603.0
#
#   domestic_release_date  ...    actor_2    actor_3    actor_4    actor_5  \
# 0            2005-07-08  ...  nm0004821  nm0262635  nm0004695  nm0573037
# 1            2005-09-16  ...  nm0000307  nm0001833  nm0001808  nm0925768
# 2            2005-05-19  ...  nm0000204  nm0000191  nm0000168  nm0001519
# 3            2004-04-02  ...  nm0427964  nm0004757  nm0000457  nm1140344
# 4            2008-03-07  ...  nm0004787  nm1304386  nm0990547  nm0269077
#
#      actor_6       director_name         writer_name        actor_1_name  \
# 0  nm0512934           Tim Story          Mark Frost       Ioan Gruffudd
# 1        NaN          Tim Burton         John August         Johnny Depp
# 2  nm0001751        George Lucas        George Lucas  Hayden Christensen
# 3  nm0734558  Guillermo del Toro  Guillermo del Toro         Ron Perlman
# 4  nm0202810     Roger Donaldson        Dick Clement       Jason Statham
#
#            actor_2_name            actor_3_name
# 0       Michael Chiklis             Chris Evans
# 1  Helena Bonham Carter            Emily Watson
# 2       Natalie Portman           Ewan McGregor
# 3            Doug Jones             Selma Blair
# 4       Saffron Burrows  Stephen Campbell Moore
#
# [5 rows x 47 columns]

# %%
model_df = model_df.merge(
    plot_franchise_df[[
        "tconst",
        "plot_summary",
        "has_plot_summary",
        "franchise"
    ]],
    on="tconst",
    how="left"
)

# %%
model_df.to_csv(
    DATA_RAW/"default_model_w_franchise_n_plot.csv",
    index=False
)
